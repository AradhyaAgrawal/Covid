# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
# import foilum
import random
from datetime import timedelta
import warnings
warnings.filterwarnings('ignore')
import plotly as py
py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv(r"C:\Users\bhagy\Desktop\BDA 594\Group Project\California_Datasets_FIXED\CSV Files\CA_cases_deaths_time_series.csv")

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#              date       county       state    fips  cases  deaths
# 0      2020-01-25       Orange  California  6059.0      1       0
# 1      2020-01-26  Los Angeles  California  6037.0      1       0
# 2      2020-01-26       Orange  California  6059.0      1       0
# 3      2020-01-27  Los Angeles  California  6037.0      1       0
# 4      2020-01-27       Orange  California  6059.0      1       0
# ...           ...          ...         ...     ...    ...     ...
# 32289  2021-09-24       Tulare  California  6107.0  74142     898
# 32290  2021-09-24     Tuolumne  California  6109.0   6365     101
# 32291  2021-09-24      Ventura  California  6111.0  98292    1134
# 32292  2021-09-24         Yolo  California  6113.0  19359     239
# 32293  2021-09-24         Yuba  California  6115.0   9755      62
#
# [32294 rows x 6 columns]

# %%
deaths=df.groupby('date').sum()['deaths'].reset_index()

# %%
deaths
# Out:
#            date  deaths
# 0    2020-01-25       0
# 1    2020-01-26       0
# 2    2020-01-27       0
# 3    2020-01-28       0
# 4    2020-01-29       0
# ..          ...     ...
# 604  2021-09-20   68158
# 605  2021-09-21   68244
# 606  2021-09-22   68402
# 607  2021-09-23   68532
# 608  2021-09-24   68710
#
# [609 rows x 2 columns]

# %%
cases=df.groupby('date').sum()['cases'].reset_index()

# %%
cases
# Out:
#            date    cases
# 0    2020-01-25        1
# 1    2020-01-26        2
# 2    2020-01-27        2
# 3    2020-01-28        2
# 4    2020-01-29        2
# ..          ...      ...
# 604  2021-09-20  4663226
# 605  2021-09-21  4669895
# 606  2021-09-22  4677452
# 607  2021-09-23  4687178
# 608  2021-09-24  4694673
#
# [609 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# date       0
# county     0
# state      0
# fips      16
# cases      0
# deaths     0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#              date       county       state    fips  cases  deaths
# 0      2020-01-25       Orange  California  6059.0      1       0
# 1      2020-01-26  Los Angeles  California  6037.0      1       0
# 2      2020-01-26       Orange  California  6059.0      1       0
# 3      2020-01-27  Los Angeles  California  6037.0      1       0
# 4      2020-01-27       Orange  California  6059.0      1       0
# ...           ...          ...         ...     ...    ...     ...
# 32289  2021-09-24       Tulare  California  6107.0  74142     898
# 32290  2021-09-24     Tuolumne  California  6109.0   6365     101
# 32291  2021-09-24      Ventura  California  6111.0  98292    1134
# 32292  2021-09-24         Yolo  California  6113.0  19359     239
# 32293  2021-09-24         Yuba  California  6115.0   9755      62
#
# [32278 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32278 entries, 0 to 32293
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    32278 non-null  object
#  1   county  32278 non-null  object
#  2   state   32278 non-null  object
#  3   fips    32278 non-null  float64
#  4   cases   32278 non-null  int64
#  5   deaths  32278 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.7+ MB

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=deaths['date'],y=deaths['deaths'],name='Deaths',line=dict(color='red')))
fig.add_trace(go.Scatter(x=deaths['date'],y=cases['cases'],name='Cases',line=dict(color='Blue')))
fig.update_layout(title='Total Active and Death Cases',xaxis_tickfont_size=14,yaxis=dict(title='Number of cases'))
fig.show()
# Out:
# <div>                            <div id="8b5cefce-d038-4c0a-a615-faccefcd61d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b5cefce-d038-4c0a-a615-faccefcd61d0")) {                    Plotly.newPlot(                        "8b5cefce-d038-4c0a-a615-faccefcd61d0",                        [{"line":{"color":"red"},"name":"Deaths","type":"scatter","x":["2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2
# ...

# %%
plt.savefig("figure.png")
